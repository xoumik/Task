# %%
data = [("Shoumik", 100), ("Alice", 200), ("Bob", 50)]
df = spark.createDataFrame(data, ["Name", "Score"])

df.write.mode("overwrite").saveAsTable("default.demo_pipeline_data")

print("Task 1: Ingestion complete!")
