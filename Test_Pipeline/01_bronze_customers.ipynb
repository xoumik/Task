# %%
# Reading from source layer
base = "/Volumes/workspace/test_pipeline/test_pipeline_volume"

df = spark.read.csv(f"{base}/olist_customers_dataset.csv", header=True)

# %%
# Writing to Bronze Layer
df.write.mode("overwrite").parquet(f"{base}/bronze/customers")
print("Bronze customers written:", df.count())
