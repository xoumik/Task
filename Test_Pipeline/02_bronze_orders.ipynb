# %%
# Read From Source 
base = "/Volumes/workspace/test_pipeline/test_pipeline_volume"

df = spark.read.csv(f"{base}/olist_orders_dataset.csv", header=True)

# %%
# Write to Bronze Layer
df.write.mode("overwrite").parquet(f"{base}/bronze/orders")
print("Bronze orders written:", df.count())
